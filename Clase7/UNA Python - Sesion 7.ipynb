# %% [markdown]
# # Python Básico

# %% [markdown]
# ## Temas
# - Librería Pandas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# PRINCIPALES LIBRERIAS A IMPORTAR
from pandas import DataFrame , read_csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Creación de Dataframes (DF)

# %%
#CREACIÓN DE UN DATAFRAME VACÍO 
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#CREACIÓN DE UN DF A PARTIR DE UNA LISTA 
data = [1,2,3,4,5]
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
# <class 'pandas.core.frame.DataFrame'>

# %%
# CREACIÓN DE UN DF A PARTIR DE UNA LISTA ANIDADA
data = [['Juan',10],['Paco',12],['Luis',13]]
df = pd.DataFrame(data,columns=['Nombre','Años'])
print(df)
print(type(df))
# Out:
#   Nombre  Años
# 0   Juan    10
# 1   Paco    12
# 2   Luis    13
# <class 'pandas.core.frame.DataFrame'>

# %%
# CREACIÓN DE UN DF A PARTIR DE UN DICCIONARIO Y LISTA
data = {'Nombre':['Tom', 'Jack', 'Steve', 'Ricky'],'Años':[28,34,29,42]} # Observe que los valores estan en una lista
df = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])
print(df)
# Out:
#       Nombre  Años
# rank1    Tom    28
# rank2   Jack    34
# rank3  Steve    29
# rank4  Ricky    42

# %%
# CREACIÓN DE UN DF A PARTIR DE UNA LISTA DE DICCIONARIOS
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
# CREACIÓN DE UN DF A PARTIR DE UNA LISTA DE DICCIONARIOS, CON ÍNDICES EN LAS FILAS
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data, index=['primero', 'segundo'])
print(df)
# Out:
#          a   b     c
# primero  1   2   NaN
# segundo  5  10  20.0

# %%
# CREACIÓN DE UN DF A PARTIR DE UNA LISTA DE DICCIONARIOS, CON ÍNDICES DE COLUMNA QUE EXISTEN (FORZANDO) 
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df1 = pd.DataFrame(data, index=['primero', 'segundo'], columns=['a', 'b'])
print(df1)
# Out:
#          a   b
# primero  1   2
# segundo  5  10

# %%
# CREACIÓN DE UN DF A PARTIR DE UNA LISTA DE DICCIONARIOS, USANDO UN ÍNDICE DE COLUMNA QUE NO EXISTE
df2 = pd.DataFrame(data, index=['primero', 'segundo'], columns=['a', 'b1'])
print(df2)
# Out:
#          a  b1
# primero  1 NaN
# segundo  5 NaN

# %%
# CREACIÓN DE UN DF A PARTIR DE UN DICCIONARIO DE SERIES
d = {'one ' : pd.Series ([1. , 2., 3.] ,index =[ 'a', 'b', 'c']) 
    ,'two ' : pd.Series ([1. , 2., 3., 4.] , index=[ 'a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)
df
# Out:
#    one   two
# a   1.0   1.0
# b   2.0   2.0
# c   3.0   3.0
# d   NaN   4.0

# %% [markdown]
# ## Lectura de información

# %%
color_table = pd.io.parsers.read_table("resourses\\Colors.txt")
print(color_table)
# Out:
#     Color  Value
# 0     Red      1
# 1  Orange      2
# 2  Yellow      3
# 3   Green      4
# 4    Blue      5
# 5  Purple      6
# 6   Black      7
# 7   White      8

# %%
# obtengo la información del dataframe
color_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Color   8 non-null      object
#  1   Value   8 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 260.0+ bytes

# %%
# verifica el tipo de las columnas
color_table.dtypes
# Out:
# Color    object
# Value     int64
# dtype: object

# %%
# verifica el tipo de una columna (en este caso Value) en especial
color_table.Value.dtype
# Out:
# dtype('int64')

# %%
#cabeza
# extrae primeros valores basado en el indice de head
# varie el número y observe el comportamiento
# utilize valores negativos y observe el comportamiento
color_table.head(1)
# Out:
#   Color  Value
# 0   Red      1

# %%
# Cola
# extrae  valores basado en el indice pero esta vez a partir del final 
# varie el número y observe el comportamiento
# utilize valores negativos y observe el comportamiento
color_table.tail(1)
# Out:
#    Color  Value
# 7  White      8

# %%
# muestra las columnas y tipos
color_table.columns
# Out:
# Index(['Color', 'Value'], dtype='object')

# %%
# muestra los valores pero en forma de array
color_table.values
# Out:
# array([['Red', 1],
#        ['Orange', 2],
#        ['Yellow', 3],
#        ['Green', 4],
#        ['Blue', 5],
#        ['Purple', 6],
#        ['Black', 7],
#        ['White', 8]], dtype=object)

# %%
# muestra como estan conformado los índices
color_table.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# extrae el valor máximo
color_table['Value'].max()
# Out:
# 8

# %%
# extrae el valor mínimo
color_table['Value'].min()
# Out:
# 1

# %%
# extrae los valores por columna , pero solamente muestra los únicos
color_table['Color'].unique()
# Out:
# array(['Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Purple', 'Black',
#        'White'], dtype=object)

# %%
# muestra una descripción completa de valores matemáticos/numéricos del dataframe
color_table.describe()
# Out:
#          Value
# count  8.00000
# mean   4.50000
# std    2.44949
# min    1.00000
# 25%    2.75000
# 50%    4.50000
# 75%    6.25000
# max    8.00000

# %% [markdown]
# ## Modificar un Dataframe

# %%
# agregar una nueva columna al dataframe
color_table["Color_Esp"] = ['Rojo', 'Naranja', 'Amarillo', 'Verde', 'Azul', 'Purpura', 'Negro','Blanco']

# %%
color_table
# Out:
#     Color  Value Color_Esp
# 0     Red      1      Rojo
# 1  Orange      2   Naranja
# 2  Yellow      3  Amarillo
# 3   Green      4     Verde
# 4    Blue      5      Azul
# 5  Purple      6   Purpura
# 6   Black      7     Negro
# 7   White      8    Blanco

# %%
# elimina una columna por medio del comando del
del color_table["Color_Esp"]
color_table
# Out:
#     Color  Value
# 0     Red      1
# 1  Orange      2
# 2  Yellow      3
# 3   Green      4
# 4    Blue      5
# 5  Purple      6
# 6   Black      7
# 7   White      8

# %%
# otra forma es mediante el uso de drop , el cual permite eliminar varias columnas al mismo tiempo

# por medio del nombre:

# agregar una nueva columna al dataframe
color_table["Color_Esp"] = ['Rojo', 'Naranja', 'Amarillo', 'Verde', 'Azul', 'Purpura', 'Negro','Blanco']
# agregar una nueva columna al dataframe
color_table["Color_Braz"] = ['Vermelho ',' Laranja ',' Amarelo ',' Verde ',' Azul ',' Roxo ',' Preto ',' Branco ']

#deplegamos el contenido
color_table
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco

# %%
# Eliminamos 2 columnas por medio de su nombre
color_table.drop(['Color_Esp', 'Color_Braz'], axis='columns', inplace=True)
color_table
# Out:
#     Color  Value
# 0     Red      1
# 1  Orange      2
# 2  Yellow      3
# 3   Green      4
# 4    Blue      5
# 5  Purple      6
# 6   Black      7
# 7   White      8

# %% [markdown]
# ### Investigación
#  - Qué funcionalidad le provee el parámetro inplace en la función drop que se mostró anteriormente? Observe el comportamiento tabto con el código anterior como el siguiente.

# %%
# agregar una nueva columna al dataframe
color_table["Color_Esp"] = ['Rojo', 'Naranja', 'Amarillo', 'Verde', 'Azul', 'Purpura', 'Negro','Blanco']
# agregar una nueva columna al dataframe
color_table["Color_Braz"] = ['Vermelho ',' Laranja ',' Amarelo ',' Verde ',' Azul ',' Roxo ',' Preto ',' Branco ']
color_table
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco

# %%
# por medio de número de columna (los índices de columna comienzan en cero)
# observe que esta vez se tuvo que sobreescribir el dataframe "color_table", esto es porque este tipo de drop no actua
# directamente sobre el objeto, sino que retorna la modificación sin afectar , esto es lo que el parámetro  inplace provee 

color_table.drop(color_table.columns[[2, 3]], axis='columns')
color_table
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco

# %% [markdown]
# ## Concatenar DF

# %%
# Agregar una fila al dataframe por medio de concat 
color_table2 = pd.DataFrame([['Brown',9]], columns=["Color", "Value"])

color_table = pd.concat([color_table,color_table2], ignore_index=True)

print(color_table)
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco
# 8   Brown      9       NaN        NaN

# %% [markdown]
# ## Investigación
# - 1. Cómo remuevo una fila en el Dataframe?
# - 2. Cómo remuevo un rango de  filas en el Dataframe?
# - 3. Cómo remuevo una fila con determinado valor

# %%
#Caso 1 : pro medio de índice de fila
color_table.drop(0)
# Out:
#     Color  Value Color_Esp Color_Braz
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco
# 8   Brown      9       NaN        NaN

# %%
#caso 2: por medio de múltiples índices
color_table.drop([1,2,3])
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco
# 8   Brown      9       NaN        NaN

# %%
# Caso 3: Por medio de valor de busqueda
color_table.drop(color_table[color_table['Color'] == 'Brown'].index)
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco

# %%
# Caso 3 alternativa: Por medio de valor de busqueda
color_table[color_table.Color != 'Brown']
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco

# %% [markdown]
# ## Ordenar un DF

# %%
color_table.sort_values("Color", ascending=False, inplace=True)
color_table
# Out:
#     Color  Value Color_Esp Color_Braz
# 2  Yellow      3  Amarillo   Amarelo
# 7   White      8    Blanco    Branco
# 0     Red      1      Rojo  Vermelho
# 5  Purple      6   Purpura      Roxo
# 1  Orange      2   Naranja   Laranja
# 3   Green      4     Verde     Verde
# 8   Brown      9       NaN        NaN
# 4    Blue      5      Azul      Azul
# 6   Black      7     Negro     Preto

# %%
# Ordena por valores de columnas dados
color_table.sort_values(["Value","Color"], ascending=True, inplace=True)
color_table
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco
# 8   Brown      9       NaN        NaN

# %% [markdown]
# ## Acceso a datos de Dataflow

# %%
# Acceso por nombre de columna. 
# IMP: El acceso por índices no es permitido.
color_table["Color"]
# Out:
# 0       Red
# 1    Orange
# 2    Yellow
# 3     Green
# 4      Blue
# 5    Purple
# 6     Black
# 7     White
# 8     Brown
# Name: Color, dtype: object

# %%
# agregar una nueva columna
color_table["Color_Esp"] = ['Rojo', 'Naranja', 'Amarillo', 'Verde', 'Azul', 'Purpura', 'Negro','Blanco', "Cafe"]
color_table
# Out:
#     Color  Value Color_Esp Color_Braz
# 0     Red      1      Rojo  Vermelho
# 1  Orange      2   Naranja   Laranja
# 2  Yellow      3  Amarillo   Amarelo
# 3   Green      4     Verde     Verde
# 4    Blue      5      Azul      Azul
# 5  Purple      6   Purpura      Roxo
# 6   Black      7     Negro     Preto
# 7   White      8    Blanco    Branco
# 8   Brown      9      Cafe        NaN

# %%
#acceso  columnas en específico
color_table[["Color_Esp","Value"]]
# Out:
#   Color_Esp  Value
# 0      Rojo      1
# 1   Naranja      2
# 2  Amarillo      3
# 3     Verde      4
# 4      Azul      5
# 5   Purpura      6
# 6     Negro      7
# 7    Blanco      8
# 8      Cafe      9

# %% [markdown]
# ## NAN's

# %% [markdown]
# - NaN, o  NOT A NUMBER, es un tipo de datos numérico que se utiliza para representar cualquier valor que no esté definido o no se pueda presentar.
# - Por ejemplo, 0/0 no está definido como un número real y, por lo tanto, está representado por NaN.
# - NaN también se asigna a variables, en un cálculo, que no tienen valores y aún no se han calculado

# %%
# agregar una nueva columna que incluye nan
color_table["Color_Port"] = ['Vermelho', 'Laranja', 'Amarelo', 'Verde', 'Azul', 'Roxo', 'Preto', 'Branco', np.nan]
color_table
# Out:
#     Color  Value Color_Esp Color_Braz Color_Port
# 0     Red      1      Rojo  Vermelho    Vermelho
# 1  Orange      2   Naranja   Laranja     Laranja
# 2  Yellow      3  Amarillo   Amarelo     Amarelo
# 3   Green      4     Verde     Verde       Verde
# 4    Blue      5      Azul      Azul        Azul
# 5  Purple      6   Purpura      Roxo        Roxo
# 6   Black      7     Negro     Preto       Preto
# 7   White      8    Blanco    Branco      Branco
# 8   Brown      9      Cafe        NaN        NaN

# %%
# despliega una matrix indicando que campos tienen o no valores nulos o nan
color_table.isnull()
# Out:
#    Color  Value  Color_Esp  Color_Braz  Color_Port
# 0  False  False      False       False       False
# 1  False  False      False       False       False
# 2  False  False      False       False       False
# 3  False  False      False       False       False
# 4  False  False      False       False       False
# 5  False  False      False       False       False
# 6  False  False      False       False       False
# 7  False  False      False       False       False
# 8  False  False      False        True        True

# %%
# otra forma de mostrar que columnas poseen valores nulos por medio de una sumatoria de ellos

color_table.isnull().sum()
# Out:
# Color         0
# Value         0
# Color_Esp     0
# Color_Braz    1
# Color_Port    1
# dtype: int64

# %%
# elimina los valores nulos 
drop_color_table = color_table.dropna()
drop_color_table
# Out:
#     Color  Value Color_Esp Color_Braz Color_Port
# 0     Red      1      Rojo  Vermelho    Vermelho
# 1  Orange      2   Naranja   Laranja     Laranja
# 2  Yellow      3  Amarillo   Amarelo     Amarelo
# 3   Green      4     Verde     Verde       Verde
# 4    Blue      5      Azul      Azul        Azul
# 5  Purple      6   Purpura      Roxo        Roxo
# 6   Black      7     Negro     Preto       Preto
# 7   White      8    Blanco    Branco      Branco

# %% [markdown]
# ### Investigación
# - 1. Cómo reemplazo los valores NAN por algún otro número, por ejemplo 0?
# - 2. Cómo puedo reemplazar algún valor por otro?
# - Tip: Revise el el uso de df.fillna() y df.replace()

# %% [markdown]
# ## Operaciones para análisis de datos. Ejemplo práctico

# %% [markdown]
# Esquema de DF de Ejemplo : Titanic.csv
#
# ![image.png](attachment:image.png)

# %%
titanic = pd.io.parsers.read_csv("resourses\\titanic.csv")
titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
generos = pd.io.parsers.read_csv("resourses\\gender.csv")
generos
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
# realizamos un merge entre las DF por medio de la llave PassengerId
lado_izq = generos
lado_der = titanic

gender_test = pd.merge(lado_izq, lado_der, on=["PassengerId"])
gender_test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Hace un merge de dataframe 'gender_test' al dataframe titanic y lo asignamos a DF
df = pd.concat([titanic, gender_test])
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
#Muestra todas la columnas
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'Survived']

# %%
#Vista general sobre las columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 836 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  836 non-null    int64
#  1   Pclass       836 non-null    int64
#  2   Name         836 non-null    object
#  3   Sex          836 non-null    object
#  4   Age          664 non-null    float64
#  5   SibSp        836 non-null    int64
#  6   Parch        836 non-null    int64
#  7   Ticket       836 non-null    object
#  8   Fare         834 non-null    float64
#  9   Cabin        182 non-null    object
#  10  Embarked     836 non-null    object
#  11  Survived     418 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.9+ KB

# %%
# Contamos columnas y filas
col_row = df.shape
print('Columnas en el  dataset:', col_row[1],'\nRows en el dataset:', col_row[0])
# Out:
# Columnas en el  dataset: 12
# Rows en el dataset: 836

# %%
# Total de celdas en el dataset 
total_cells=np.product(df.shape)
print('Total de celdas:',total_cells)
# Out:
# Total de celdas: 10032

# %% [markdown]
# ### Limpieza de datos

# %%
# buscamos duplicador 
df.duplicated().sum()
# Out:
# 0

# %%
# Buscamos los duplicados a partir de dataframe original
df.loc[titanic.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Survived]
# Index: []

# %%
#Vista general sobre las columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 836 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  836 non-null    int64
#  1   Pclass       836 non-null    int64
#  2   Name         836 non-null    object
#  3   Sex          836 non-null    object
#  4   Age          664 non-null    float64
#  5   SibSp        836 non-null    int64
#  6   Parch        836 non-null    int64
#  7   Ticket       836 non-null    object
#  8   Fare         834 non-null    float64
#  9   Cabin        182 non-null    object
#  10  Embarked     836 non-null    object
#  11  Survived     418 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.9+ KB

# %% [markdown]
# ###  Identificamos valores incorrectos (missing values)

# %%
# Buscamos la cantidad de missing values en cada columna
missing_values = df.isnull().sum().sort_values(ascending=False)
missing_values
# Out:
# Cabin          654
# Survived       418
# Age            172
# Fare             2
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Embarked         0
# dtype: int64

# %%
# Caluclamos el porcentaje de missing values:

# 1. Variable con el total de missing values 
total_missing = missing_values.sum()

# 2.  Calcula el porcentaje de missing values

percent_missing = (total_missing/total_cells) * 100

print("Total de  missing values: {}  =  {:.2f} %".format(total_missing, percent_missing))
# Out:
# Total de  missing values: 1246  =  12.42 %

# %%
number_missing = df.isnull().sum().sort_values(ascending=False)
pct_column = (df.isnull().sum() / len(df) * 100).round(2).astype('str')+' %'
pct_total = (df.isnull().sum()/df.isna().sum().sum()*100).round(2).astype('str')+' %'
missing_values = pd.concat([number_missing, pct_column, pct_total], axis=1, keys=['Numero_Missing_Values', 'PCT_Missing_Column','PCT_all_Missing'])
   
print('\nMISSING VALUES EN',df.shape[0],'FILAS:')    
all_missing = missing_values.loc[missing_values['Numero_Missing_Values'] > 0]
all_missing
# Out:
# MISSING VALUES EN 836 FILAS:
#           Numero_Missing_Values PCT_Missing_Column PCT_all_Missing
# Cabin                       654            78.23 %         52.49 %
# Survived                    418             50.0 %         33.55 %
# Age                         172            20.57 %          13.8 %
# Fare                          2             0.24 %          0.16 %

# %% [markdown]
# ### Visualización

# %%
import seaborn as sns

# %%
# Detect missing values
missing = df.isnull()

# Visualisation
plt.figure(figsize=(15,5), dpi=100)
sns.heatmap(missing,yticklabels=False, cbar=False, cmap=None)
plt.title('MISSING VALUES', size=17, pad=13)
plt.show()

# %% [markdown]
# Por medio de esta información podemos decidir quer hacer con los missimng values
# - Drop
#     - Drop todas las filas
#     - Drop todas la  columnas
#
#
# - Reemplazar los datos
#
#     - Remplazar por la media o el promedio
#     - Reemplazar por la frecuencia
#     - Replazar por algún valor determinado

# %%
# Vemos que la columna fare tiene pocos errorres , asi que podemos revisar esta
df[pd.isnull(df.Fare)]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked  Survived
# 152   NaN   NaN        S       NaN
# 152   NaN   NaN        S       0.0

# %%
# Revisamos  y contamos los values que involugra la columna Fare
df['Fare'].value_counts()
# Out:
# Fare
# 7.7500     42
# 26.0000    38
# 13.0000    34
# 8.0500     34
# 7.8958     22
#            ..
# 7.8208      2
# 8.5167      2
# 78.8500     2
# 52.0000     2
# 22.3583     2
# Name: count, Length: 169, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 836 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  836 non-null    int64
#  1   Pclass       836 non-null    int64
#  2   Name         836 non-null    object
#  3   Sex          836 non-null    object
#  4   Age          664 non-null    float64
#  5   SibSp        836 non-null    int64
#  6   Parch        836 non-null    int64
#  7   Ticket       836 non-null    object
#  8   Fare         834 non-null    float64
#  9   Cabin        182 non-null    object
#  10  Embarked     836 non-null    object
#  11  Survived     418 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.9+ KB

# %%
# Como sólo 2 valores en Fare son missing values y esto es un 0.16% del total, se utilizará el reemplazo por la media del dataframe
df["Fare"] = df["Fare"].fillna(df["Fare"].mean())

# %%
#Vista general sobre las columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 836 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  836 non-null    int64
#  1   Pclass       836 non-null    int64
#  2   Name         836 non-null    object
#  3   Sex          836 non-null    object
#  4   Age          664 non-null    float64
#  5   SibSp        836 non-null    int64
#  6   Parch        836 non-null    int64
#  7   Ticket       836 non-null    object
#  8   Fare         836 non-null    float64
#  9   Cabin        182 non-null    object
#  10  Embarked     836 non-null    object
#  11  Survived     418 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.9+ KB

# %%
# Contamos los valores 
df['Fare'].value_counts()
# Out:
# Fare
# 7.7500     42
# 26.0000    38
# 8.0500     34
# 13.0000    34
# 10.5000    22
#            ..
# 8.7125      2
# 7.8208      2
# 8.5167      2
# 78.8500     2
# 22.3583     2
# Name: count, Length: 170, dtype: int64

# %%
# Como la columna Cabin posee una gran cantidad de missing values, es mejor eliminar la columna
# Deleting the column
df.drop("Cabin", axis=1, inplace=True)

# %%
# Verificamos que las columna  "Cabin" fue borrada
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked  Survived
# 0  34.5      0      0   330911   7.8292        Q       NaN
# 1  47.0      1      0   363272   7.0000        S       NaN
# 2  62.0      0      0   240276   9.6875        Q       NaN
# 3  27.0      0      0   315154   8.6625        S       NaN
# 4  22.0      1      1  3101298  12.2875        S       NaN

# %% [markdown]
# Para el caso de age tenemos un porcentaje alto , pero no deseamos borrar los datos. Asi que vamos a analizar que hacer

# %%
df.Age.describe().to_frame()
# Out:
#              Age
# count  664.00000
# mean    30.27259
# std     14.17051
# min      0.17000
# 25%     21.00000
# 50%     27.00000
# 75%     39.00000
# max     76.00000

# %%
# The histogramm shows the age distribution of all passengers
df['Age'].hist(bins=16, color='purple' ,figsize=(16,7))
plt.title('Distribución por edad de los pasajeros', size=17, pad=13)
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked  Survived
# 0  34.5      0      0   330911   7.8292        Q       NaN
# 1  47.0      1      0   363272   7.0000        S       NaN
# 2  62.0      0      0   240276   9.6875        Q       NaN
# 3  27.0      0      0   315154   8.6625        S       NaN
# 4  22.0      1      1  3101298  12.2875        S       NaN

# %%
# Mean vs. median de Age
display(df.Age.mean())
display(df.Age.median())
# Out:
# 30.272590361445783
# 27.0

# %%
# Agrupamos por la  columna 'Sex' y ver el promedio por edad de mujeres y hombres
grouped_sex_age = df.groupby(['Sex']).Age.agg([len, 'min', 'max', 'mean', 'median'])
grouped_sex_age
# Out:
#         len   min   max       mean  median
# Sex
# female  304  0.17  76.0  30.272362    27.0
# male    532  0.33  67.0  30.272732    27.0

# %%
# Agrupamos por  'Pclass'  y ver el promedio por Edad  de clase a clase
grouped_class_age = df.groupby(['Pclass']).Age.agg([len, 'min', 'max', 'mean', 'median'])
grouped_class_age
# Out:
#         len   min   max       mean  median
# Pclass
# 1       214  6.00  76.0  40.918367    42.0
# 2       186  0.92  63.0  28.777500    26.5
# 3       436  0.17  60.5  24.027945    24.0

# %%
# Verificamos el average de age y cantidad de personas por cada clase y sexo

grouped_sex_pclass_age = df.groupby(['Sex', 'Pclass']).Age.agg([len, 'min', 'max', 'mean', 'median'])
grouped_sex_pclass_age
# Out:
#                len    min   max       mean  median
# Sex    Pclass
# female 1       100  18.00  76.0  41.333333    41.0
#        2        60   0.92  60.0  24.376552    24.0
#        3       144   0.17  47.0  23.073400    22.0
# male   1       114   6.00  67.0  40.520000    42.0
#        2       126   2.00  63.0  30.940678    28.0
#        3       292   0.33  60.5  24.525104    24.0

# %% [markdown]
# La edad media en cada clase y sexo es muy diferente. También podría haber una correlación entre Age y SibSp (hermanos y esposos), así que podríamos incluir esta relación

# %%
# Verificamos  Age y  la cantidad de personas por cada  clase ,  sexo y  SibSp
grouped_sex_pclass_age = df.groupby(['Pclass', 'SibSp']).Age.agg([len, 'min', 'max', 'mean', 'median'])
grouped_sex_pclass_age
# Out:
#               len    min   max       mean  median
# Pclass SibSp
# 1      0      122   6.00  64.0  38.711538    39.0
#        1       84  18.00  76.0  43.857143    46.0
#        2        6  13.00  59.0  42.333333    55.0
#        3        2  28.00  28.0  28.000000    28.0
# 2      0      124   8.00  62.0  29.517544    27.0
#        1       54   0.92  63.0  28.589630    29.0
#        2        8  12.00  24.0  19.500000    21.0
# 3      0      320   0.33  60.5  25.692000    24.0
#        1       82   0.17  50.0  20.568571    20.0
#        2       14  17.00  22.0  19.500000    19.5
#        3        6   6.00  31.0  22.000000    29.0
#        4        8   5.00  38.0  16.500000    11.5
#        5        2  10.00  10.0  10.000000    10.0
#        8        4  14.50  14.5  14.500000    14.5

# %%
fem_p1_s0 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 0)].Age.median()
fem_p1_s1 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 1)].Age.median()
fem_p1_s2 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 2)].Age.median()
fem_p1_s3 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 3)].Age.median()
fem_p2_s0 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 0)].Age.median()
fem_p2_s1 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 1)].Age.median()
fem_p2_s2 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 2)].Age.median()
fem_p2_s3 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 3)].Age.median()
fem_p3_s0 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 0)].Age.median()
fem_p3_s1 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 1)].Age.median()
fem_p3_s2 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 2)].Age.median()
fem_p3_s3 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 3)].Age.median()
fem_p3_s4 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 4)].Age.median()
fem_p3_s5 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 5)].Age.median()
fem_p3_s8 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 8)].Age.median()
male_p1_s0 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 0)].Age.median()
male_p1_s1 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 1)].Age.median()
male_p1_s2 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 2)].Age.median()
male_p1_s3 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 3)].Age.median()
male_p2_s0 =df.loc[(df.Sex == 'male') & (df.Pclass == 2) & (df.SibSp == 0)].Age.median()
male_p2_s1 =df.loc[(df.Sex == 'male') & (df.Pclass == 2) & (df.SibSp == 1)].Age.median()
male_p2_s2 =df.loc[(df.Sex == 'male') & (df.Pclass == 2) & (df.SibSp == 2)].Age.median()
male_p3_s0 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 0)].Age.median()
male_p3_s1 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 1)].Age.median()
male_p3_s2 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 2)].Age.median()
male_p3_s3 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 3)].Age.median()
male_p3_s4 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 4)].Age.median()
male_p3_s5 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 5)].Age.median()
male_p3_s6 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 6)].Age.median()
male_p3_s8 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 8)].Age.median()

# %%
def myfunc(age, pclass, sex, SibSp):
    if pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 0:
        age=fem_p1_s0
    elif pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 1:
        age=fem_p1_s1
    elif pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 2:
        age=fem_p1_s2
    elif pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 3:
        age=fem_p1_s3      
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 0:
        age=fem_p2_s0
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 1:
        age=fem_p2_s1
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 2:
        age=fem_p2_s2
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 3:
        age=fem_p2_s3
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 0:
        age=fem_p3_s0
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 1:
        age=fem_p3_s1
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 2:
        age=fem_p3_s2
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 3:
        age=fem_p3_s3
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 4:
        age=fem_p3_s4
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 5:
        age=fem_p3_s5  
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 8:
        age=df.Age.median()  
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 0:
        age=male_p1_s0
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 1:
        age=male_p1_s1
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 2:
        age=male_p1_s2
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 3:
        age=male_p1_s3      
    elif pd.isnull(age) and pclass==2 and sex == 'male' and SibSp == 0:
        age=male_p2_s0
    elif pd.isnull(age) and pclass==2 and sex == 'male' and SibSp == 1:
        age=male_p2_s1
    elif pd.isnull(age) and pclass==2 and sex == 'male' and SibSp == 2:
        age=male_p2_s2   
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 0:
        age=male_p3_s0
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 1:
        age=male_p3_s1
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 2:
        age=male_p3_s2
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 3:
        age=male_p3_s3
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 4:
        age=male_p3_s4
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 5:
        age=male_p3_s5
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 6:
        age=male_p3_s6
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 8:
        age=male_p3_s8 
    else:
        age=age
    return age

# %%
# Creamos una nueva columna  'Age_Filled_Na' con el nuevo average de valor de Age 
df['Age_Filled'] = df.apply(lambda x: myfunc(x['Age'], x['Pclass'], x['Sex'], x['SibSp']), axis=1)

# %%
# Verificamos la nueva columna creada
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked  Survived  Age_Filled
# 0  34.5      0      0   330911   7.8292        Q       NaN        34.5
# 1  47.0      1      0   363272   7.0000        S       NaN        47.0
# 2  62.0      0      0   240276   9.6875        Q       NaN        62.0
# 3  27.0      0      0   315154   8.6625        S       NaN        27.0
# 4  22.0      1      1  3101298  12.2875        S       NaN        22.0

# %%
# Verificamos si quedan  missing values en Age_Filled 
df.Age_Filled.isnull().sum()
# Out:
# 0

# %%
# Histograma de distribución por edad con los nuevos valores 
df['Age_Filled'].hist(bins=16, color='purple' ,figsize=(16,8))
plt.title('Distribución de Pasajeros por Edad ')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)

# %%
# analizamos todo el dataframe
df.describe(include='all')
# Out:
#         PassengerId      Pclass              Name   Sex        Age  \
# count    836.000000  836.000000               836   836  664.00000
# unique          NaN         NaN               418     2        NaN
# top             NaN         NaN  Kelly, Mr. James  male        NaN
# freq            NaN         NaN                 2   532        NaN
# mean    1100.500000    2.265550               NaN   NaN   30.27259
# std      120.738094    0.841333               NaN   NaN   14.17051
# min      892.000000    1.000000               NaN   NaN    0.17000
# 25%      996.000000    1.000000               NaN   NaN   21.00000
# 50%     1100.500000    3.000000               NaN   NaN   27.00000
# 75%     1205.000000    3.000000               NaN   NaN   39.00000
# max     1309.000000    3.000000               NaN   NaN   76.00000
#
#              SibSp       Parch    Ticket        Fare Embarked    Survived  \
# count   836.000000  836.000000       836  836.000000      836  418.000000
# ...

# %%
# Verificamos los tipo de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 836 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  836 non-null    int64
#  1   Pclass       836 non-null    int64
#  2   Name         836 non-null    object
#  3   Sex          836 non-null    object
#  4   Age          664 non-null    float64
#  5   SibSp        836 non-null    int64
#  6   Parch        836 non-null    int64
#  7   Ticket       836 non-null    object
#  8   Fare         836 non-null    float64
#  9   Embarked     836 non-null    object
#  10  Survived     418 non-null    float64
#  11  Age_Filled   836 non-null    float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 84.9+ KB

# %%
# Creamos una nueva columna 'Sex_Number' con valores  '1' para  'female' y '0' para 'male'
df['Sex_Number'] = np.where((df['Sex'] == "female"), 1, 0)
# verificamos
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked  Survived  Age_Filled  \
# 0  34.5      0      0   330911   7.8292        Q       NaN        34.5
# 1  47.0      1      0   363272   7.0000        S       NaN        47.0
# 2  62.0      0      0   240276   9.6875        Q       NaN        62.0
# 3  27.0      0      0   315154   8.6625        S       NaN        27.0
# 4  22.0      1      1  3101298  12.2875        S       NaN        22.0
#
#    Sex_Number
# 0           0
# 1           1
# 2           0
# ...

# %%
# reemplazamos los missing values de Survived por 0 , que indica que no sobrevivieron
#df['Survived'].fillna(0,inplace=True)
df['Survived'] = df['Survived'].fillna(0)
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
df_final = df.drop(['Sex','Embarked','Ticket','Age','Name'],axis=1)
df_final.head()
# Out:
#    PassengerId  Pclass  SibSp  Parch     Fare  Survived  Age_Filled  \
# 0          892       3      0      0   7.8292       0.0        34.5
# 1          893       3      1      0   7.0000       0.0        47.0
# 2          894       2      0      0   9.6875       0.0        62.0
# 3          895       3      0      0   8.6625       0.0        27.0
# 4          896       3      1      1  12.2875       0.0        22.0
#
#    Sex_Number
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 836 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  836 non-null    int64
#  1   Pclass       836 non-null    int64
#  2   SibSp        836 non-null    int64
#  3   Parch        836 non-null    int64
#  4   Fare         836 non-null    float64
#  5   Survived     836 non-null    float64
#  6   Age_Filled   836 non-null    float64
#  7   Sex_Number   836 non-null    int32
# dtypes: float64(3), int32(1), int64(4)
# memory usage: 55.5 KB

# %%
# Reseteo los indices dado que algunas columnas fueron eliminadas 
df_final.reset_index(drop=True, inplace=True)

# %%
# Creo la tabla de correlación 
correlation = df_final.corr()
correlation
# Out:
#              PassengerId    Pclass     SibSp     Parch      Fare  Survived  \
# PassengerId     1.000000 -0.026751  0.003818  0.043080  0.008209 -0.014496
# Pclass         -0.026751  1.000000  0.001087  0.018721 -0.576619 -0.067733
# SibSp           0.003818  0.001087  1.000000  0.306895  0.171488  0.062326
# Parch           0.043080  0.018721  0.306895  1.000000  0.230001  0.099229
# Fare            0.008209 -0.576619  0.171488  0.230001  1.000000  0.119348
# Survived       -0.014496 -0.067733  0.062326  0.099229  0.119348  1.000000
# Age_Filled     -0.041901 -0.530405 -0.084801 -0.068887  0.349323 -0.003369
# Sex_Number     -0.023245 -0.108615  0.099943  0.159120  0.191382  0.623610
#
#              Age_Filled  Sex_Number
# PassengerId   -0.041901   -0.023245
# Pclass        -0.530405   -0.108615
# SibSp         -0.084801    0.099943
# Parch         -0.068887    0.159120
# Fare           0.349323    0.191382
# Survived      -0.003369    0.623610
# ...

# %%
# muestra la matrix de correlación pero usando el efecto de mapeo por colores
corrMatrix = df_final.corr()
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f0fc4_row0_col0, #T_f0fc4_row1_col1, #T_f0fc4_row2_col2, #T_f0fc4_row3_col3, #T_f0fc4_row4_col4, #T_f0fc4_row5_col5, #T_f0fc4_row6_col6, #T_f0fc4_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f0fc4_row0_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f0fc4_row0_col2, #T_f0fc4_row1_col2, #T_f0fc4_row1_col3, #T_f0fc4_row3_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f0fc4_row0_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f0fc4_row0_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f0fc4_row0_col5, #T_f0fc4_row4_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f0fc4_row0_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f0fc4_row0_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f0fc4_row1_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# ...

# %%
#Correlación Age vrs Fare
df_final[["Age_Filled","Fare"]].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d9af2_row0_col0, #T_d9af2_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d9af2_row0_col1, #T_d9af2_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d9af2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9af2_level0_col0" class="col_heading level0 col0" >Age_Filled</th>
#       <th id="T_d9af2_level0_col1" class="col_heading level0 col1" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9af2_level0_row0" class="row_heading level0 row0" >Age_Filled</th>
#       <td id="T_d9af2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d9af2_row0_col1" class="data row0 col1" >0.349323</td>
#     </tr>
#     <tr>
#       <th id="T_d9af2_level0_row1" class="row_heading level0 row1" >Fare</th>
#       <td id="T_d9af2_row1_col0" class="data row1 col0" >0.349323</td>
# ...

# %%
# muestra la varianza entre los datos
df_final.var()
# Out:
# PassengerId    14577.687425
# Pclass             0.707842
# SibSp              0.803215
# Parch              0.962049
# Fare            3114.427169
# Survived           0.148938
# Age_Filled       169.568962
# Sex_Number         0.231682
# dtype: float64

# %%
# muestra la covarianza entre los datos
covMatrix = df_final.cov()
covMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_669bb_row0_col0, #T_669bb_row1_col1, #T_669bb_row4_col2, #T_669bb_row4_col3, #T_669bb_row4_col4, #T_669bb_row4_col5, #T_669bb_row4_col6, #T_669bb_row4_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_669bb_row0_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_669bb_row0_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_669bb_row0_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_669bb_row0_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_669bb_row0_col5, #T_669bb_row0_col6, #T_669bb_row0_col7, #T_669bb_row1_col4, #T_669bb_row4_col1, #T_669bb_row6_col0, #T_669bb_row6_col2, #T_669bb_row6_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_669bb_row1_col0, #T_669bb_row2_col0, #T_669bb_row3_col0, #T_669bb_row5_col0, #T_669bb_row7_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_669bb_row1_col2 {
#   background-color: #5a78e4;
# ...

# %% [markdown]
# ### Renombramiento de Columnas

# %%
df_final = df_final.rename(columns={'Survived': 'estado','Sex_Number': 'sexo', 'Age_Filled': 'edad'})
df_final
# Out:
#      PassengerId  Pclass  SibSp  Parch      Fare  estado  edad  sexo
# 0            892       3      0      0    7.8292     0.0  34.5     0
# 1            893       3      1      0    7.0000     0.0  47.0     1
# 2            894       2      0      0    9.6875     0.0  62.0     0
# 3            895       3      0      0    8.6625     0.0  27.0     0
# 4            896       3      1      1   12.2875     0.0  22.0     1
# ..           ...     ...    ...    ...       ...     ...   ...   ...
# 831         1305       3      0      0    8.0500     0.0  25.0     0
# 832         1306       1      0      0  108.9000     1.0  39.0     1
# 833         1307       3      0      0    7.2500     0.0  38.5     0
# 834         1308       3      0      0    8.0500     0.0  25.0     0
# 835         1309       3      1      1   22.3583     0.0  21.0     0
#
# [836 rows x 8 columns]

# %% [markdown]
# ### Conversión de tipos

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  836 non-null    int64
#  1   Pclass       836 non-null    int64
#  2   SibSp        836 non-null    int64
#  3   Parch        836 non-null    int64
#  4   Fare         836 non-null    float64
#  5   estado       836 non-null    float64
#  6   edad         836 non-null    float64
#  7   sexo         836 non-null    int32
# dtypes: float64(3), int32(1), int64(4)
# memory usage: 49.1 KB

# %%
# convierto a un tipo especifico la columna
# Edad es un float pero deseamos que este sea un número entero
df_final['edad']=df_final['edad'].astype('int')
df_final
# Out:
#      PassengerId  Pclass  SibSp  Parch      Fare  estado  edad  sexo
# 0            892       3      0      0    7.8292     0.0    34     0
# 1            893       3      1      0    7.0000     0.0    47     1
# 2            894       2      0      0    9.6875     0.0    62     0
# 3            895       3      0      0    8.6625     0.0    27     0
# 4            896       3      1      1   12.2875     0.0    22     1
# ..           ...     ...    ...    ...       ...     ...   ...   ...
# 831         1305       3      0      0    8.0500     0.0    25     0
# 832         1306       1      0      0  108.9000     1.0    39     1
# 833         1307       3      0      0    7.2500     0.0    38     0
# 834         1308       3      0      0    8.0500     0.0    25     0
# 835         1309       3      1      1   22.3583     0.0    21     0
#
# [836 rows x 8 columns]

# %% [markdown]
# ### Graficación de un dataframe

# %%
male = (df_final['sexo'] == 1).sum()
female = (df_final['sexo'] == 0).sum()
proportions = [male,female]

plt.figure(figsize=(12,8), dpi=77)
plt.pie(proportions, data=df, labels= ['Hombres', 'Mujeres'], explode = (0.05,0), startangle=90, autopct='%1.1f%%', shadow=False)
plt.axis('equal')
plt.title("Proporción por Género", size=17, pad=13)
plt.show()

# %%
# Cantidad de sobrevivientes  por edad utilizando el group by
df_final.groupby(['estado']).edad.agg([len,'min', 'max','mean', 'median'])
# Out:
#         len  min  max       mean  median
# estado
# 0.0     684    0   76  29.269006    25.0
# 1.0     152    0   76  29.184211    24.5

# %%
import matplotlib.pyplot as plt
# rangos 
range = (0, 100) 
bins = 5 # agrupamiento

# plot 
plt.hist(df_final['edad'], bins, range, color = 'blue',histtype = 'bar', rwidth = 0.8) 



# etiquetas de los ejes 
plt.xlabel('Edad') 
plt.ylabel('No. de personas') 
# titulo del plot  
plt.title('Histograma') 
# muestra el plot
plt.show()

# %%
# Sexo y edad comparado con si sobrevivio
g = sns.FacetGrid(df_final, col='estado', sharey=False, ylim=(0,80), hue='sexo', height=7, aspect=1.1)
g.map_dataframe(sns.histplot, x='edad')
g.set_axis_labels('Edad', 'Cantidad')
g.add_legend()
plt.show()

# %%
# Sobrevivientes y no  comparados por la clase de tiquete
plt.figure(figsize=(10,8), dpi=77)
sns.countplot(x=df_final['Pclass'],hue=df_final['estado'])
plt.title("Comparación: Sobreviviente - Ticket Class", size=17, pad=13)
plt.legend(['No Sobreviviente', 'Sobreviviente'], loc='upper left', prop={'size': 12})
plt.show()

# %%
plt.figure(figsize=(12,6), dpi=77)
sns.barplot(x="Parch", y="estado", data=df_final)
plt.title("Posibilidad de sobrevicir si tenia padres e hijos en le barco", size=17, pad=13)
plt.xlabel('Num de  Padres / Hijos ')
plt.show()

# %% [markdown]
# ## Ejercicio
# -  1. Trate con sus propios cambios explorando los parámetros: orientation,  cumulative, bottom , histtype , align , bins
# - Puede hacer consultas en https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html#matplotlib.pyplot.hist
